# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("C:/Users/IFC-36/Downloads/car_data.csv")

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
df.max()
# Out:
# Car_Name              xcent
# Year                   2018
# Selling_Price          35.0
# Present_Price          92.6
# Kms_Driven           500000
# Fuel_Type            Petrol
# Seller_Type      Individual
# Transmission         Manual
# Owner                     3
# dtype: object

# %%
df.min()
# Out:
# Car_Name               800
# Year                  2003
# Selling_Price          0.1
# Present_Price         0.32
# Kms_Driven             500
# Fuel_Type              CNG
# Seller_Type         Dealer
# Transmission     Automatic
# Owner                    0
# dtype: object

# %%
x=df['Year']
y=df['Selling_Price']
plt.scatter(x,y)
plt.show()

# %%
plt.pie(df.Fuel_Type.value_counts(), labels=["Petrol","Diesel","CNG"],shadow = True)
plt.show()

# %%
column_counts = df['Fuel_Type'].value_counts()
print(column_counts)
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
df.Fuel_Type.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Fuel_Type'>

# %%
df.Fuel_Type.value_counts().plot.barh()
# Out:
# <Axes: ylabel='Fuel_Type'>

# %%
column_counts = df['Fuel_Type'].value_counts()
print(column_counts)
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
column_counts = df['Seller_Type'].value_counts()
print(column_counts)
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
column_counts = df['Transmission'].value_counts()
print(column_counts)
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %%
df.Transmission.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Transmission'>

# %%
column_counts = df['Owner'].value_counts()
print(column_counts)
# Out:
# Owner
# 0    290
# 1     10
# 3      1
# Name: count, dtype: int64

# %%
df.Owner.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Owner'>

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
column_counts = df['Car_Name'].value_counts()
print(column_counts)
# Out:
# Car_Name
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: count, Length: 98, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define figure dimensions
fig_dims = (12, 20)
fig, ax = plt.subplots(figsize=fig_dims)

# Create a count plot with purple color
sns.countplot(y='Car_Name', data=df, ax=ax, color='purple')

# Display the plot
plt.title('Count of Car Names', fontsize=16)
plt.xlabel('Count', fontsize=14)
plt.ylabel('Car Name', fontsize=14)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
#From which manufacturing year to which manufacturing year vehicles are present in this data ?
min_year = df["Year"].min()
max_year = df["Year"].max()

min_year, max_year
# Out:
# (2003, 2018)

# %%
# Get the lowest selling price
lowest_price = df["Selling_Price"].min()
lowest_price
# Out:
# 0.1

# %%
# Get the highest selling price
highest_price = df["Selling_Price"].max()
highest_price
# Out:
# 35.0

# %%
# Get the number of records (rows) in the dataset
num_records = df.shape[0]
num_records
# Out:
# 301

# %%
# Check for missing values in the dataset
missing_values = df.isnull().sum()
missing_values
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
# Get the number of  different vehicles are present in this data
num_unique_vehicles = df["Car_Name"].nunique()
num_unique_vehicles
# Out:
# 98

# %%
# Find the most sold vehicle (car name with the highest count)
most_sold_vehicle = df["Car_Name"].value_counts().idxmax()
most_sold_count = df["Car_Name"].value_counts().max()

most_sold_vehicle, most_sold_count
# Out:
# ('city', 26)

# %%
# Check if there are any CNG vehicles and count them
cng_vehicle_count = df[df["Fuel_Type"] == "CNG"].shape[0]
cng_vehicle_count
# Out:
# 2

# %%
# Count the number of vehicles being sold by individuals
num_individual_sales = df[df["Seller_Type"] == "Individual"].shape[0]
num_individual_sales
# Out:
# 106

# %%
# Check if there are any automatic transmission vehicles and count them
auto_transmission_count = df[df["Transmission"] == "Automatic"].shape[0]
auto_transmission_count
# Out:
# 40

# %%
# Count the number of single-owner vehicles (Owner == 0)
single_owner_vehicles = df[df["Owner"] == 0].shape[0]
single_owner_vehicles
# Out:
# 290

# %%
# Calculate depreciation for each vehicle
df["Depreciation"] = df["Present_Price"] - df["Selling_Price"]

# Find the most depreciated vehicle (highest depreciation)
most_depreciated = df.loc[df["Depreciation"].idxmax()]

# Find the least depreciated vehicle (lowest depreciation)
least_depreciated = df.loc[df["Depreciation"].idxmin()]

most_depreciated[["Car_Name", "Year", "Present_Price", "Selling_Price", "Depreciation"]], \
least_depreciated[["Car_Name", "Year", "Present_Price", "Selling_Price", "Depreciation"]]
# Out:
# (Car_Name         land cruiser
#  Year                     2010
#  Present_Price            92.6
#  Selling_Price            35.0
#  Depreciation             57.6
#  Name: 86, dtype: object,
#  Car_Name         Honda Activa 4G
#  Year                        2017
#  Present_Price               0.51
#  Selling_Price               0.48
#  Depreciation                0.03
#  Name: 155, dtype: object)

# %%
# Extract brand names from the "Car_Name" column (assuming the first word represents the brand)
df["Brand"] = df["Car_Name"].apply(lambda x: x.split()[0])

# Calculate depreciation percentage
df["Depreciation"] = ((df["Present_Price"] - df["Selling_Price"]) / df["Present_Price"]) * 100

# Compute average depreciation per brand
brand_depreciation = df.groupby("Brand")["Depreciation"].mean().sort_values()

# Display brands with the least depreciation (top 5)
brand_depreciation.head(5)
# Out:
# Brand
# vitara     5.900305
# UM         6.593407
# creta     13.235294
# grand     13.267544
# ignis     14.185639
# Name: Depreciation, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
correlation_year = df["Selling_Price"].corr(df["Year"])
correlation_kms = df["Selling_Price"].corr(df["Kms_Driven"])

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.scatterplot(x=df["Year"], y=df["Selling_Price"], alpha=0.7)
plt.title(f"Selling Price vs. Year\nCorrelation: {correlation_year:.2f}")
plt.xlabel("Manufacturing Year")
plt.ylabel("Selling Price")
plt.subplot(1, 2, 2)
sns.scatterplot(x=df["Kms_Driven"], y=df["Selling_Price"], alpha=0.7)
plt.title(f"Selling Price vs. Kms Driven\nCorrelation: {correlation_kms:.2f}")
plt.xlabel("Kms Driven")
plt.ylabel("Selling Price")

plt.tight_layout()
plt.show()
correlation_year, correlation_kms
# Out:
# (0.23614098016042737, 0.029187090674291236)

# %%
# Filter the dataset for vehicles manufactured after 2014
new_vehicles = df[df["Year"] > 2014]
new_vehicles.head()
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
#
#   Seller_Type Transmission  Owner  Depreciation   Brand
# 2      Dealer       Manual      0          2.60    ciaz
# 5      Dealer       Manual      0          0.58  vitara
# 6      Dealer       Manual      0          1.37    ciaz
# 7      Dealer       Manual      0          2.11       s
# 8      Dealer       Manual      0          0.14    ciaz

# %%
#data of only two wheelers from this data ?
two_wheelers = df[df["Car_Name"].str.contains("Activa|Pulsar|Splendor|Apache|Dio|Jupiter", case=False, na=False)]
print(two_wheelers)
# Out:
#                  Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 120    Bajaj Pulsar RS200  2016           1.05          1.260        5700
# 134    TVS Apache RTR 160  2017           0.65          0.810       11800
# 135      Bajaj Pulsar 150  2015           0.65          0.740        5000
# 144  Bajaj Pulsar  NS 200  2014           0.60          0.990       25000
# 145    TVS Apache RTR 160  2012           0.60          0.810       19000
# 148    Bajaj Pulsar 220 F  2010           0.52          0.940       45000
# 149    Bajaj Pulsar 220 F  2016           0.51          0.940       24000
# 150    TVS Apache RTR 180  2011           0.50          0.826        6000
# 152   Bajaj Pulsar NS 200  2012           0.50          0.990       13000
# 153   Bajaj Pulsar NS 200  2013           0.50          0.990       45000
# 155       Honda Activa 4G  2017           0.48          0.510        4300
# 159       Honda Activa 4G  2017           0.45          0.510        4000
# ...

# %%
#oldest bike sold here
bike_names = ["Activa", "Pulsar", "Splendor", "Apache", "Dio", "Jupiter"]  
bikes_df = df[df["Car_Name"].str.contains("|".join(bike_names), case=False, na=False)]

# Find the oldest bike
oldest_bike = bikes_df[bikes_df["Year"] == bikes_df["Year"].min()]
print(oldest_bike)
# Out:
#                 Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 189  Hero Super Splendor  2005            0.2           0.57       55000
#
#     Fuel_Type Seller_Type Transmission  Owner  Depreciation Brand
# 189    Petrol  Individual       Manual      0          0.37  Hero

# %%
#newest bike sold here
bike_names = ["Activa", "Pulsar", "Splendor", "Apache", "Dio", "Jupiter"]  
bikes_df = df[df["Car_Name"].str.contains("|".join(bike_names), case=False, na=False)]

# Find the newest bike
newest_bike = bikes_df[bikes_df["Year"] == bikes_df["Year"].max()]
print(newest_bike)
# Out:
#                Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 134  TVS Apache RTR 160  2017           0.65           0.81       11800
# 155     Honda Activa 4G  2017           0.48           0.51        4300
# 159     Honda Activa 4G  2017           0.45           0.51        4000
# 173           Activa 4g  2017           0.40           0.51        1300
#
#     Fuel_Type Seller_Type Transmission  Owner  Depreciation   Brand
# 134    Petrol  Individual       Manual      0          0.16     TVS
# 155    Petrol  Individual    Automatic      0          0.03   Honda
# 159    Petrol  Individual    Automatic      0          0.06   Honda
# 173    Petrol  Individual    Automatic      0          0.11  Activa

# %%
bike_names = ["Activa", "Pulsar", "Splendor", "Apache", "Dio", "Jupiter"]  
bikes_df = df[df["Car_Name"].str.contains("|".join(bike_names), case=False, na=False)]

# Find the most sold bike
most_sold_bike = bikes_df["Car_Name"].value_counts().idxmax()
print("Most sold bike:", most_sold_bike)
# Out:
# Most sold bike: Bajaj Pulsar 150

# %%
# Step 1: Identify two-wheelers in the dataset
bike_names = ["Activa", "Pulsar", "Splendor", "Apache", "Dio", "Jupiter"]  
bikes_df = df[df["Car_Name"].str.contains("|".join(bike_names), case=False, na=False)]
bikes_df["Price_Difference"] = bikes_df["Selling_Price"] / bikes_df["Present_Price"]  
unusual_deals = bikes_df[bikes_df["Price_Difference"] > bikes_df["Price_Difference"].quantile(0.95)]  

# Step 3: Display the unusual deals
print(unusual_deals)
# Out:
#             Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 155  Honda Activa 4G  2017           0.48           0.51        4300
# 159  Honda Activa 4G  2017           0.45           0.51        4000
#
#     Fuel_Type Seller_Type Transmission  Owner  Depreciation  Brand  \
# 155    Petrol  Individual    Automatic      0          0.03  Honda
# 159    Petrol  Individual    Automatic      0          0.06  Honda
#
#      Price_Difference
# 155          0.941176
# 159          0.882353
# C:\Users\IFC-36\AppData\Local\Temp\ipykernel_3940\1251209436.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bikes_df["Price_Difference"] = bikes_df["Selling_Price"] / bikes_df["Present_Price"]  # Ratio of selling vs. original price

# %%
# Step 1: List unique vehicle names (to check for bikes)
print(df["Car_Name"].unique())

# Step 2: Define common bike names
bike_names = ["Activa", "Pulsar", "Splendor", "Apache", "Dio", "Jupiter"] 

# Step 3: Filter out cars by excluding bikes
cars_df = df[~df["Car_Name"].str.contains("|".join(bike_names), case=False, na=False)]

# Step 4: Display first few records of only cars
print(cars_df.head())
# Out:
# ['ritz' 'sx4' 'ciaz' 'wagon r' 'swift' 'vitara brezza' 's cross'
#  'alto 800' 'ertiga' 'dzire' 'alto k10' 'ignis' '800' 'baleno' 'omni'
#  'fortuner' 'innova' 'corolla altis' 'etios cross' 'etios g' 'etios liva'
#  'corolla' 'etios gd' 'camry' 'land cruiser' 'Royal Enfield Thunder 500'
#  'UM Renegade Mojave' 'KTM RC200' 'Bajaj Dominar 400'
#  'Royal Enfield Classic 350' 'KTM RC390' 'Hyosung GT250R'
#  'Royal Enfield Thunder 350' 'KTM 390 Duke ' 'Mahindra Mojo XT300'
#  'Bajaj Pulsar RS200' 'Royal Enfield Bullet 350'
#  'Royal Enfield Classic 500' 'Bajaj Avenger 220' 'Bajaj Avenger 150'
#  'Honda CB Hornet 160R' 'Yamaha FZ S V 2.0' 'Yamaha FZ 16'
#  'TVS Apache RTR 160' 'Bajaj Pulsar 150' 'Honda CBR 150' 'Hero Extreme'
#  'Bajaj Avenger 220 dtsi' 'Bajaj Avenger 150 street' 'Yamaha FZ  v 2.0'
#  'Bajaj Pulsar  NS 200' 'Bajaj Pulsar 220 F' 'TVS Apache RTR 180'
#  'Hero Passion X pro' 'Bajaj Pulsar NS 200' 'Yamaha Fazer '
#  'Honda Activa 4G' 'TVS Sport ' 'Honda Dream Yuga '
# ...

# %%
# Find the oldest car based on the 'Year' column
oldest_car = df[df["Year"] == df["Year"].min()]

# Display the oldest car(s)
print(oldest_car)
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 37      800  2003           0.35           2.28      127000    Petrol
# 39      sx4  2003           2.25           7.98       62000    Petrol
#
#    Seller_Type Transmission  Owner  Depreciation Brand
# 37  Individual       Manual      0          1.93   800
# 39      Dealer       Manual      0          5.73   sx4

# %%
# Find the newest car based on the 'Year' column
newest_car = df[df["Year"] == df["Year"].max()]

# Display the newest car(s)
print(newest_car)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
#
#   Seller_Type Transmission  Owner  Depreciation   Brand
# 5      Dealer       Manual      0          0.58  vitara

# %%
# Step 1: Calculate the price difference ratio (Selling Price / Present Price)
df["Price_Ratio"] = df["Selling_Price"] / df["Present_Price"]

# Step 2: Find deals where the price ratio is unusually high (top 5% deals)
unusual_deals = df[df["Price_Ratio"] > df["Price_Ratio"].quantile(0.95)]

# Step 3: Display the unusual deals
print(unusual_deals)
# Out:
#                Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 5         vitara brezza  2018           9.25           9.83        2071
# 8                  ciaz  2016           8.75           8.89       20273
# 80        corolla altis  2016          14.73          14.89       23000
# 83               innova  2015          12.50          13.46       38000
# 101  UM Renegade Mojave  2017           1.70           1.82        1400
# 102           KTM RC200  2017           1.65           1.78        4000
# 126   Bajaj Avenger 220  2017           0.90           0.95        1300
# 127   Bajaj Avenger 150  2016           0.75           0.80        7000
# 129   Yamaha FZ S V 2.0  2017           0.78           0.84        5000
# 155     Honda Activa 4G  2017           0.48           0.51        4300
# 208                 i20  2017           7.90           8.10        3435
# 231               verna  2017           9.25           9.40       15001
# ...
