# %%
#impoting seaborn library
import seaborn as sns
import matplotlib.pyplot as plt
# displaying plots in jupyter notebook
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips. head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.histplot(tips['total_bill'], kde=False, color='purple')
plt.show()

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='scatter' ,color='orange')
plt.show()

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex', color='red', height=8)
plt.show()

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg',color='yellow')
plt.show()

# %%
sns.pairplot(tips)
plt.show()

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')
plt.show()

# %%
sns.barplot(x='sex',y='total_bill',data=tips,color='green')
plt.show()

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Assuming 'tips' is a DataFrame
sns.barplot(x='sex', y='total_bill', data=tips, estimator=np.std, color='orange')

# Show the plot
plt.show()

# %%
sns.countplot(x='sex',data=tips,color='skyblue')
plt.show()

# %%
sns.boxplot(x="day", y="total_bill", data=tips, hue="day", palette='rainbow')
plt.show()

# %%
# Can do entire dataframe with orient='h'
sns.boxplot(data=tips,palette='rainbow',orient='h')
plt.show()

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips, palette="coolwarm")
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", data=tips, hue="day", palette='rainbow', legend=False)
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',palette='Set1')
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',split=True,palette='Set1')
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", data=tips,color='pink')
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True,color='black')
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True,hue='sex',palette='Set1')
plt.show()

# %%
flights = sns.load_dataset('flights')

# %%
tips = sns.load_dataset('tips')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns for the correlation matrix
numeric_cols = tips.select_dtypes(include=['number'])

# Create the heatmap of the correlation matrix for numeric columns
plt.figure(figsize=(8, 6))
sns.heatmap(numeric_cols.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns
numeric_cols = tips.select_dtypes(include=['number'])

# Create a heatmap of the correlation matrix for numeric columns
plt.figure(figsize=(8, 6))  # Optional: Set the figure size for better readability
sns.heatmap(numeric_cols.corr(), cmap='coolwarm', annot=True, fmt='.2f', linewidths=0.5)

# Display the plot
plt.show()
